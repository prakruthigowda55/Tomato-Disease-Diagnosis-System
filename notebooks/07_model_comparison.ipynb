# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": [
        "Custom CNN",
        "EfficientNetB0"
    ],
    "Accuracy": [
        93.40,
        96.88
    ]
})

comparison
# Out:
#             Model  Accuracy
# 0      Custom CNN     93.40
# 1  EfficientNetB0     96.88

# %%
comparison.to_csv(
    "../results/model_comparison.csv",
    index=False
)

print("Comparison Saved")
# Out:
# Comparison Saved
