# %%
import os

dataset_path = "../dataset/disease"

classes = os.listdir(dataset_path)

print("Classes:")
for cls in classes:
    print(cls)
# Out:
# Classes:
# Tomato_Early_blight
# Tomato_healthy
# Tomato_Late_blight
# Tomato_Leaf_Mold

# %%
import os

dataset_path = "../dataset/disease"

for cls in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, cls)
    num_images = len(os.listdir(folder_path))
    print(f"{cls}: {num_images} images")
# Out:
# Tomato_Early_blight: 1000 images
# Tomato_healthy: 1591 images
# Tomato_Late_blight: 1909 images
# Tomato_Leaf_Mold: 952 images

# %%
import os
import cv2
import matplotlib.pyplot as plt

image_folder = "../dataset/disease/Tomato_Early_blight"

image_name = os.listdir(image_folder)[0]

image_path = os.path.join(image_folder, image_name)

img = cv2.imread(image_path)

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Tomato Early Blight")
plt.axis("off")
plt.show()

# %%
print("Image Shape:", img.shape)
# Out:
# Image Shape: (256, 256, 3)

# %%
for cls in os.listdir("../dataset/disease"):
    folder = os.path.join("../dataset/disease", cls)

    first_image = os.listdir(folder)[0]

    image_path = os.path.join(folder, first_image)

    img = cv2.imread(image_path)

    print(cls, "->", img.shape)
# Out:
# Tomato_Early_blight -> (256, 256, 3)
# Tomato_healthy -> (256, 256, 3)
# Tomato_Late_blight -> (256, 256, 3)
# Tomato_Leaf_Mold -> (256, 256, 3)
